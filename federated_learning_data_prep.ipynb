# %%
# !pip install opendatasets

# %%
# !pip install tensorflow

# %%
# !pip install tensorflow_federated

# %%
# !nvidia-smi

# %%
# !pip install torch==1.9.0+cu111 torchvision==0.10.0+cu111 torchaudio===0.9.0 -f https://download.pytorch.org/whl/torch_stable.html

# %%
import opendatasets as od
od.download("https://www.kaggle.com/prashant268/chest-xray-covid19-pneumonia")
od.download("https://www.kaggle.com/sudalairajkumar/novel-corona-virus-2019-dataset")

# %%
import torch
import torchvision
from torchvision import datasets, transforms
import numpy as np

# %%
LEARNING_RATE = 0.001 # 0.0001
MAX_EPOCHS = 10
TARGET_FOLDER = "weights"

# %%
transform = transforms.Compose([transforms.Resize((244, 244))
                                , transforms.ToTensor()]
                               #, transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]) # find mean and std of dataset
                              )

test_set = datasets.ImageFolder('chest-xray-covid19-pneumonia/Data/test', transform=transform)

train_set = dataset = datasets.ImageFolder('chest-xray-covid19-pneumonia/Data/train', transform=transform)

# %%
def label_preparation(labels):
    labels = np.array(labels)
    labels[labels > 0] = 1
    return list(labels)

def label_preparation_tensor(labels):
    labels[labels > 0] = 1
    return labels

train_set.targets = label_preparation(train_set.targets)

test_set.targets = label_preparation(test_set.targets)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

print(f"Current device: {device}")
# Out:
# Current device: cuda:0

# %%
def calc_accuracy(result, labels):
    result = torch.sigmoid(result).round()
    
    correct_results_sum = (result == labels).sum().float()
    acc = correct_results_sum/labels.shape[0]
    acc *= 100
    
    return acc

# %% [markdown]
# # Federated

# %%
number_of_clients = 4

# %%
from collections import OrderedDict

def update_client(federated_model, client):
    client.load_state_dict(federated_model.state_dict(), True)
    return client
    
def federated_average(federated_model, client_models):
    average_weights = OrderedDict()
    
    number_of_clients = len(client_models)
    for client_model in client_models:
        for key, value in client_model.state_dict().items():
            if key in average_weights:
                average_weights[key] += (1./number_of_clients) * value.clone()
            else:
                average_weights[key] = (1./number_of_clients) * value.clone()
                
                
    federated_model.load_state_dict(average_weights, True)
    return federated_model

# %%
def train_federated(model, data_loader, optimizer, loss):
    """
    model -- neural net
    data_loader -- dataloader for train images
    optimizer -- optimizer
    """
    model.train()
    
    accuracy = 0
    for step, [images, labels] in enumerate(data_loader, 1):
        images = images.to(device)
        labels = label_preparation_tensor(labels.to(device))

        optimizer.zero_grad()
        
        result = model(images)
        targets = labels.float()

        loss_value = loss(result.float(), targets)

        # backpropagation
        loss_value.backward()
        optimizer.step()
                                    
        if step % 10 == 0:
            accuracy += calc_accuracy(result, targets)
            print(f"TRAINING - Step: {step}, loss: {loss_value}, rolling accuracy: {accuracy*10/step}")

# %%
def test_federated(model, test_loader, loss):
    """    
    model -- neural net 
    test_loader -- dataloader of test images
    epoch -- current epoch
    """
    model.eval()
    model.to(device)
    
    with torch.no_grad():
        loss_value = 0
        accuracy = 0
        for step, [images, labels] in enumerate(test_loader, 1):
            images = images.to(device)
            labels = label_preparation_tensor(labels.to(device))

            result = model(images)
            targets = labels.detach().unsqueeze(1).float()

            loss_value += loss(result.detach(), targets)
            accuracy += calc_accuracy(result.detach(), targets)

        loss_value /= step
        accuracy /=  step
        
        if device.type == "cuda": 
            torch.cuda.empty_cache()
      
    model.to("cpu")
    print(f"TESTING - Loss: {loss_value}, Accuracy: {accuracy}")
    return accuracy

# %%
def run_federated_training(federated_model, client_models, client_training_loader):
    # use pos weights because of unbalanced data set
    federated_loss = torch.nn.BCEWithLogitsLoss(pos_weight=torch.tensor([1./10])).to(device) # binary crossentropy
    # federated_loss = torch.nn.CrossEntropyLoss(weight=torch.tensor([1./10])).to(device) # sparce categorical crossentropy (federated)

    # start training
    for epoch in range(MAX_EPOCHS):
        for client_idx in range (number_of_clients):
            print(f"+++ FEDERATED MODEL {client_idx}, EPOCH: {epoch+1} +++++++++")

            client_model = client_models[client_idx]
            client_model.to(device)
            client_model = update_client(federated_model, client_model)
            client_optimizer = torch.optim.Adam(client_model.parameters())
        
            train_federated(client_model, client_training_loader[client_idx], client_optimizer, federated_loss)
        
            if device.type == "cuda": 
                torch.cuda.empty_cache()
            
            client_model.to("cpu")
            
            # save interim weights
            #torch.save(client_model.state_dict(), f'./{TARGET_FOLDER}/client_model_{client_idx}_epoch_{epoch}.ckpt')

        federated_model = federated_average(federated_model, client_models)
        
        # save interim weights
        #torch.save(federated_model.state_dict(), f'./{TARGET_FOLDER}/epoch_{epoch}.ckpt')
        
        if test_federated(federated_model, federated_test_loader, federated_loss) > 97 and epoch >= 4:
            print("Early return: SUCCESS")
            return

# %%
class DatasetWithTransform(torch.utils.data.Dataset):
    dataset: torch.utils.data.Dataset
    transform: torchvision.transforms.Compose

    def __init__(self, dataset: torch.utils.data.Dataset, transform: torchvision.transforms.Compose) -> None:
        self.dataset = dataset
        self.transform = transform
                      
    def __getitem__(self, index):
        x, y = self.dataset[index]
        x = self.transform(x)
        y = torch.Tensor([y])
        return x, y

    def __len__(self):
        return len(self.dataset)

# %%
from typing import List, Tuple

def prepare_train_data(
    train_set: torch.utils.data.Dataset,
    no_of_clients: int,
    augment_data: bool,
    full_data_on_each_client: bool,
    batch_size=32, shuffle=True, num_workers=0, pin_memory=True
) -> List[torch.utils.data.DataLoader]:
    
    if augment_data:
        # flip, shift & rotate
        transform = transforms.Compose([
            transforms.ToPILImage(),
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.RandomVerticalFlip(p=0.5),
            transforms.RandomAffine(degrees=90, translate=(0.2,0.2)),
            transforms.ToTensor()
        ])
    else:
        transform = transforms.Compose([transforms.ToPILImage(), transforms.ToTensor()])
    
    data_loaders = []
    if full_data_on_each_client:
        data_loaders = [
            torch.utils.data.DataLoader(
                DatasetWithTransform(train_set, transform),
                batch_size=batch_size, shuffle=shuffle, num_workers=num_workers, pin_memory=pin_memory
            )
        for _ in range(no_of_clients)]
    else:
        chunk_size_train = len(train_set) // no_of_clients
        indices_train = np.random.permutation(np.arange(chunk_size_train * no_of_clients)) 

        for idx in range(no_of_clients):
            data_loader_train = torch.utils.data.Subset(train_set, indices_train[idx*chunk_size_train:(idx+1)*chunk_size_train])
            data_loaders += [
                torch.utils.data.DataLoader(
                    DatasetWithTransform(data_loader_train, transform),
                    batch_size=batch_size, shuffle=shuffle, num_workers=num_workers, pin_memory=pin_memory
                )
            ]
    
    return data_loaders

# %%
federated_model = torchvision.models.resnet18(pretrained=False, num_classes=1)
federated_test_loader = torch.utils.data.DataLoader(test_set, batch_size=32, shuffle=False, num_workers=0)
client_models = [torchvision.models.resnet18(pretrained=False, num_classes=1) for _ in range(number_of_clients)]

train_loader_no_split_no_augment = prepare_train_data(train_set, number_of_clients, augment_data=False, full_data_on_each_client=True)

run_federated_training(federated_model, client_models, train_loader_no_split_no_augment)

train_loader_no_split_no_augment = None
# Out:
# +++ FEDERATED MODEL 0, EPOCH: 1 +++++++++
# C:\Users\Donat\anaconda3\lib\site-packages\torch\nn\functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  ..\c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# TRAINING - Step: 10, loss: 0.050081975758075714, rolling accuracy: 90.625
# TRAINING - Step: 20, loss: 0.022462524473667145, rolling accuracy: 92.1875
# TRAINING - Step: 30, loss: 0.01131326425820589, rolling accuracy: 93.75000762939453
# TRAINING - Step: 40, loss: 0.04491039365530014, rolling accuracy: 91.40625
# TRAINING - Step: 50, loss: 0.023222673684358597, rolling accuracy: 91.875
# TRAINING - Step: 60, loss: 0.045296888798475266, rolling accuracy: 90.10417175292969
# TRAINING - Step: 70, loss: 0.06982383131980896, rolling accuracy: 90.625
# TRAINING - Step: 80, loss: 0.03420264273881912, rolling accuracy: 89.84375
# TRAINING - Step: 90, loss: 0.005413800943642855, rolling accuracy: 90.97222137451172
# TRAINING - Step: 100, loss: 0.03828900307416916, rolling accuracy: 90.3125
# TRAINING - Step: 110, loss: 0.024426111951470375, rolling accuracy: 90.625
# TRAINING - Step: 120, loss: 0.02831759862601757, rolling accuracy: 91.14583587646484
# TRAINING - Step: 130, loss: 0.008062878623604774, rolling accuracy: 91.34615325927734
# TRAINING - Step: 140, loss: 0.010797559283673763, rolling accuracy: 91.96428680419922
# TRAINING - Step: 150, loss: 0.04130817577242851, rolling accuracy: 91.875
# TRAINING - Step: 160, loss: 0.0053371828980743885, rolling accuracy: 92.3828125
# +++ FEDERATED MODEL 1, EPOCH: 1 +++++++++
# TRAINING - Step: 10, loss: 0.08454311639070511, rolling accuracy: 71.875
# TRAINING - Step: 20, loss: 0.05659184977412224, rolling accuracy: 82.8125
# TRAINING - Step: 30, loss: 0.052289221435785294, rolling accuracy: 86.45833587646484
# TRAINING - Step: 40, loss: 0.02551726996898651, rolling accuracy: 88.28125
# TRAINING - Step: 50, loss: 0.03284022957086563, rolling accuracy: 90.0
# TRAINING - Step: 60, loss: 0.050816237926483154, rolling accuracy: 91.14583587646484
# TRAINING - Step: 70, loss: 0.026444843038916588, rolling accuracy: 91.51786041259766
# TRAINING - Step: 80, loss: 0.033455461263656616, rolling accuracy: 91.40625
# TRAINING - Step: 90, loss: 0.021511198952794075, rolling accuracy: 91.31945037841797
# TRAINING - Step: 100, loss: 0.045992981642484665, rolling accuracy: 91.25
# TRAINING - Step: 110, loss: 0.019203510135412216, rolling accuracy: 91.19317626953125
# TRAINING - Step: 120, loss: 0.028031373396515846, rolling accuracy: 91.66667175292969
# TRAINING - Step: 130, loss: 0.011184291914105415, rolling accuracy: 92.30769348144531
# TRAINING - Step: 140, loss: 0.0441601388156414, rolling accuracy: 91.74107360839844
# TRAINING - Step: 150, loss: 0.04990497976541519, rolling accuracy: 91.66667175292969
# TRAINING - Step: 160, loss: 0.012963605113327503, rolling accuracy: 91.9921875
# +++ FEDERATED MODEL 2, EPOCH: 1 +++++++++
# TRAINING - Step: 10, loss: 0.1422518789768219, rolling accuracy: 84.375
# TRAINING - Step: 20, loss: 0.06027837097644806, rolling accuracy: 84.375
# TRAINING - Step: 30, loss: 0.04323357716202736, rolling accuracy: 86.45833587646484
# TRAINING - Step: 40, loss: 0.0559348538517952, rolling accuracy: 86.71875
# TRAINING - Step: 50, loss: 0.049227505922317505, rolling accuracy: 85.625
# TRAINING - Step: 60, loss: 0.023131880909204483, rolling accuracy: 86.45833587646484
# TRAINING - Step: 70, loss: 0.021575964987277985, rolling accuracy: 87.05357360839844
# TRAINING - Step: 80, loss: 0.034948695451021194, rolling accuracy: 87.890625
# TRAINING - Step: 90, loss: 0.015101834200322628, rolling accuracy: 88.8888931274414
# TRAINING - Step: 100, loss: 0.01978270150721073, rolling accuracy: 89.0625
# TRAINING - Step: 110, loss: 0.030874939635396004, rolling accuracy: 89.48863220214844
# TRAINING - Step: 120, loss: 0.01775631122291088, rolling accuracy: 90.10417175292969
# TRAINING - Step: 130, loss: 0.0033236434683203697, rolling accuracy: 90.86538696289062
# TRAINING - Step: 140, loss: 0.020015526562929153, rolling accuracy: 91.07142639160156
# TRAINING - Step: 150, loss: 0.008924150839447975, rolling accuracy: 91.45833587646484
# TRAINING - Step: 160, loss: 0.03841318190097809, rolling accuracy: 91.015625
# +++ FEDERATED MODEL 3, EPOCH: 1 +++++++++
# TRAINING - Step: 10, loss: 0.07409343123435974, rolling accuracy: 87.5
# TRAINING - Step: 20, loss: 0.12730926275253296, rolling accuracy: 87.5
# TRAINING - Step: 30, loss: 0.05395770072937012, rolling accuracy: 85.41667175292969
# TRAINING - Step: 40, loss: 0.034416645765304565, rolling accuracy: 85.9375
# TRAINING - Step: 50, loss: 0.1006290465593338, rolling accuracy: 86.875
# TRAINING - Step: 60, loss: 0.0646977573633194, rolling accuracy: 87.50000762939453
# TRAINING - Step: 70, loss: 0.012289931997656822, rolling accuracy: 88.83928680419922
# TRAINING - Step: 80, loss: 0.026990115642547607, rolling accuracy: 89.453125
# TRAINING - Step: 90, loss: 0.07694192975759506, rolling accuracy: 89.58333587646484
# TRAINING - Step: 100, loss: 0.023220552131533623, rolling accuracy: 89.375
# TRAINING - Step: 110, loss: 0.009752809070050716, rolling accuracy: 89.7727279663086
# TRAINING - Step: 120, loss: 0.03735487908124924, rolling accuracy: 89.84375762939453
# TRAINING - Step: 130, loss: 0.027475038543343544, rolling accuracy: 89.66345977783203
# TRAINING - Step: 140, loss: 0.027379006147384644, rolling accuracy: 89.73213958740234
# TRAINING - Step: 150, loss: 0.05337611585855484, rolling accuracy: 90.20833587646484
# TRAINING - Step: 160, loss: 0.012651622295379639, rolling accuracy: 90.8203125
# TESTING - Loss: 0.27217766642570496, Accuracy: 91.15853118896484
# +++ FEDERATED MODEL 0, EPOCH: 2 +++++++++
# TRAINING - Step: 10, loss: 0.10601191222667694, rolling accuracy: 90.625
# TRAINING - Step: 20, loss: 0.026290057227015495, rolling accuracy: 95.3125
# TRAINING - Step: 30, loss: 0.029991894960403442, rolling accuracy: 93.75000762939453
# TRAINING - Step: 40, loss: 0.04520606994628906, rolling accuracy: 90.625
# TRAINING - Step: 50, loss: 0.017844807356595993, rolling accuracy: 91.875
# TRAINING - Step: 60, loss: 0.02233056351542473, rolling accuracy: 91.14583587646484
# TRAINING - Step: 70, loss: 0.020913200452923775, rolling accuracy: 91.07142639160156
# TRAINING - Step: 80, loss: 0.022233713418245316, rolling accuracy: 91.40625
# TRAINING - Step: 90, loss: 0.04824473336338997, rolling accuracy: 90.625
# TRAINING - Step: 100, loss: 0.016731442883610725, rolling accuracy: 90.9375
# TRAINING - Step: 110, loss: 0.018981341272592545, rolling accuracy: 91.4772720336914
# TRAINING - Step: 120, loss: 0.011861607432365417, rolling accuracy: 92.18750762939453
# TRAINING - Step: 130, loss: 0.05958012491464615, rolling accuracy: 92.30769348144531
# TRAINING - Step: 140, loss: 0.06113966554403305, rolling accuracy: 91.96428680419922
# TRAINING - Step: 150, loss: 0.014029281213879585, rolling accuracy: 91.875
# TRAINING - Step: 160, loss: 0.0339907705783844, rolling accuracy: 91.6015625
# +++ FEDERATED MODEL 1, EPOCH: 2 +++++++++
# TRAINING - Step: 10, loss: 0.02447345294058323, rolling accuracy: 90.625
# TRAINING - Step: 20, loss: 0.041864462196826935, rolling accuracy: 90.625
# TRAINING - Step: 30, loss: 0.011907695792615414, rolling accuracy: 93.75000762939453
# TRAINING - Step: 40, loss: 0.029284564778208733, rolling accuracy: 93.75
# TRAINING - Step: 50, loss: 0.01946265809237957, rolling accuracy: 95.0
# TRAINING - Step: 60, loss: 0.07014915347099304, rolling accuracy: 93.22917175292969
# TRAINING - Step: 70, loss: 0.030437111854553223, rolling accuracy: 92.41071319580078
# TRAINING - Step: 80, loss: 0.05617383494973183, rolling accuracy: 92.96875
# TRAINING - Step: 90, loss: 0.031446631997823715, rolling accuracy: 92.36111450195312
# TRAINING - Step: 100, loss: 0.03662014752626419, rolling accuracy: 92.1875
# TRAINING - Step: 110, loss: 0.025668833404779434, rolling accuracy: 92.32954406738281
# TRAINING - Step: 120, loss: 0.05692322179675102, rolling accuracy: 92.70833587646484
# TRAINING - Step: 130, loss: 0.016362177208065987, rolling accuracy: 92.54808044433594
# TRAINING - Step: 140, loss: 0.02112346515059471, rolling accuracy: 92.41071319580078
# TRAINING - Step: 150, loss: 0.06705988943576813, rolling accuracy: 92.5
# TRAINING - Step: 160, loss: 0.01155184768140316, rolling accuracy: 92.7734375
# +++ FEDERATED MODEL 2, EPOCH: 2 +++++++++
# TRAINING - Step: 10, loss: 0.014255831949412823, rolling accuracy: 96.875
# TRAINING - Step: 20, loss: 0.06465552747249603, rolling accuracy: 93.75
# TRAINING - Step: 30, loss: 0.025781646370887756, rolling accuracy: 93.75000762939453
# TRAINING - Step: 40, loss: 0.01668170839548111, rolling accuracy: 94.53125
# TRAINING - Step: 50, loss: 0.0321396142244339, rolling accuracy: 95.625
# TRAINING - Step: 60, loss: 0.15118177235126495, rolling accuracy: 90.62500762939453
# TRAINING - Step: 70, loss: 0.00391416298225522, rolling accuracy: 91.96428680419922
# TRAINING - Step: 80, loss: 0.01864749565720558, rolling accuracy: 92.96875
# TRAINING - Step: 90, loss: 0.06693791598081589, rolling accuracy: 93.40277862548828
# TRAINING - Step: 100, loss: 0.040872469544410706, rolling accuracy: 91.875
# TRAINING - Step: 110, loss: 0.01573413610458374, rolling accuracy: 92.32954406738281
# TRAINING - Step: 120, loss: 0.029136471450328827, rolling accuracy: 92.44792175292969
# TRAINING - Step: 130, loss: 0.029816988855600357, rolling accuracy: 92.78845977783203
# TRAINING - Step: 140, loss: 0.038741081953048706, rolling accuracy: 92.63392639160156
# TRAINING - Step: 150, loss: 0.03776372969150543, rolling accuracy: 92.91667175292969
# TRAINING - Step: 160, loss: 0.031836964190006256, rolling accuracy: 92.578125
# +++ FEDERATED MODEL 3, EPOCH: 2 +++++++++
# TRAINING - Step: 10, loss: 0.08774489909410477, rolling accuracy: 96.875
# TRAINING - Step: 20, loss: 0.037379179149866104, rolling accuracy: 95.3125
# TRAINING - Step: 30, loss: 0.059432849287986755, rolling accuracy: 91.66667175292969
# TRAINING - Step: 40, loss: 0.05499568209052086, rolling accuracy: 91.40625
# TRAINING - Step: 50, loss: 0.005426174961030483, rolling accuracy: 93.125
# TRAINING - Step: 60, loss: 0.03200949728488922, rolling accuracy: 92.70833587646484
# TRAINING - Step: 70, loss: 0.022000113502144814, rolling accuracy: 92.85713958740234
# TRAINING - Step: 80, loss: 0.02035638689994812, rolling accuracy: 93.359375
# TRAINING - Step: 90, loss: 0.015755068510770798, rolling accuracy: 93.40277862548828
# TRAINING - Step: 100, loss: 0.05514134094119072, rolling accuracy: 93.125
# TRAINING - Step: 110, loss: 0.004889731295406818, rolling accuracy: 93.75
# TRAINING - Step: 120, loss: 0.01975640282034874, rolling accuracy: 93.75000762939453
# TRAINING - Step: 130, loss: 0.019782010465860367, rolling accuracy: 93.75
# TRAINING - Step: 140, loss: 0.008967231027781963, rolling accuracy: 93.97321319580078
# TRAINING - Step: 150, loss: 0.13215243816375732, rolling accuracy: 93.75
# TRAINING - Step: 160, loss: 0.016792181879281998, rolling accuracy: 93.75
# TESTING - Loss: 0.0981425866484642, Accuracy: 94.9695053100586
# +++ FEDERATED MODEL 0, EPOCH: 3 +++++++++
# TRAINING - Step: 10, loss: 0.027846653014421463, rolling accuracy: 84.375
# TRAINING - Step: 20, loss: 0.04898057132959366, rolling accuracy: 85.9375
# TRAINING - Step: 30, loss: 0.10223836451768875, rolling accuracy: 88.54167175292969
# TRAINING - Step: 40, loss: 0.026533061638474464, rolling accuracy: 90.625
# TRAINING - Step: 50, loss: 0.08227631449699402, rolling accuracy: 90.0
# TRAINING - Step: 60, loss: 0.07183974981307983, rolling accuracy: 89.58333587646484
# TRAINING - Step: 70, loss: 0.012504423968493938, rolling accuracy: 90.625
# TRAINING - Step: 80, loss: 0.010005383752286434, rolling accuracy: 91.796875
# TRAINING - Step: 90, loss: 0.009524625726044178, rolling accuracy: 92.0138931274414
# TRAINING - Step: 100, loss: 0.008159566670656204, rolling accuracy: 92.8125
# TRAINING - Step: 110, loss: 0.010022774338722229, rolling accuracy: 92.8977279663086
# TRAINING - Step: 120, loss: 0.005866499617695808, rolling accuracy: 93.48958587646484
# TRAINING - Step: 130, loss: 0.013583233579993248, rolling accuracy: 93.99038696289062
# TRAINING - Step: 140, loss: 0.01768077351152897, rolling accuracy: 94.19642639160156
# TRAINING - Step: 150, loss: 0.020846843719482422, rolling accuracy: 93.95833587646484
# TRAINING - Step: 160, loss: 0.023664718493819237, rolling accuracy: 93.9453125
# +++ FEDERATED MODEL 1, EPOCH: 3 +++++++++
# TRAINING - Step: 10, loss: 0.01431955210864544, rolling accuracy: 90.625
# TRAINING - Step: 20, loss: 0.11000190675258636, rolling accuracy: 89.0625
# TRAINING - Step: 30, loss: 0.01451655849814415, rolling accuracy: 89.58333587646484
# TRAINING - Step: 40, loss: 0.011757051572203636, rolling accuracy: 90.625
# TRAINING - Step: 50, loss: 0.020021900534629822, rolling accuracy: 91.25
# TRAINING - Step: 60, loss: 0.010509269312024117, rolling accuracy: 91.66667175292969
# TRAINING - Step: 70, loss: 0.02811790071427822, rolling accuracy: 91.96428680419922
# TRAINING - Step: 80, loss: 0.017221659421920776, rolling accuracy: 92.578125
# TRAINING - Step: 90, loss: 0.014813685789704323, rolling accuracy: 92.70833587646484
# TRAINING - Step: 100, loss: 0.04729430377483368, rolling accuracy: 92.1875
# TRAINING - Step: 110, loss: 0.014643709175288677, rolling accuracy: 92.04544830322266
# TRAINING - Step: 120, loss: 0.05504272133111954, rolling accuracy: 91.92708587646484
# TRAINING - Step: 130, loss: 0.01476719044148922, rolling accuracy: 92.54808044433594
# TRAINING - Step: 140, loss: 0.06400217860937119, rolling accuracy: 92.85713958740234
# TRAINING - Step: 150, loss: 0.08172929286956787, rolling accuracy: 91.875
# TRAINING - Step: 160, loss: 0.009662913158535957, rolling accuracy: 92.3828125
# +++ FEDERATED MODEL 2, EPOCH: 3 +++++++++
# TRAINING - Step: 10, loss: 0.034260090440511703, rolling accuracy: 87.5
# TRAINING - Step: 20, loss: 0.03268371522426605, rolling accuracy: 93.75
# TRAINING - Step: 30, loss: 0.021933631971478462, rolling accuracy: 94.79167175292969
# TRAINING - Step: 40, loss: 0.008619336411356926, rolling accuracy: 96.09375
# TRAINING - Step: 50, loss: 0.022445054724812508, rolling accuracy: 96.25
# TRAINING - Step: 60, loss: 0.031543489545583725, rolling accuracy: 95.31250762939453
# TRAINING - Step: 70, loss: 0.01014328096061945, rolling accuracy: 95.53571319580078
# TRAINING - Step: 80, loss: 0.012611931189894676, rolling accuracy: 95.3125
# TRAINING - Step: 90, loss: 0.011770086362957954, rolling accuracy: 95.48611450195312
# TRAINING - Step: 100, loss: 0.01695818081498146, rolling accuracy: 95.3125
# TRAINING - Step: 110, loss: 0.014341359958052635, rolling accuracy: 95.45454406738281
# TRAINING - Step: 120, loss: 0.02763710357248783, rolling accuracy: 95.05208587646484
# TRAINING - Step: 130, loss: 0.038894955068826675, rolling accuracy: 94.71154022216797
# TRAINING - Step: 140, loss: 0.004660631995648146, rolling accuracy: 95.08928680419922
# TRAINING - Step: 150, loss: 0.037974536418914795, rolling accuracy: 94.79167175292969
# TRAINING - Step: 160, loss: 0.05624766647815704, rolling accuracy: 94.7265625
# +++ FEDERATED MODEL 3, EPOCH: 3 +++++++++
# TRAINING - Step: 10, loss: 0.02658226154744625, rolling accuracy: 90.625
# TRAINING - Step: 20, loss: 0.0029805428348481655, rolling accuracy: 95.3125
# TRAINING - Step: 30, loss: 0.007219882681965828, rolling accuracy: 96.87500762939453
# TRAINING - Step: 40, loss: 0.03034493513405323, rolling accuracy: 95.3125
# TRAINING - Step: 50, loss: 0.04553619772195816, rolling accuracy: 95.0
# TRAINING - Step: 60, loss: 0.020714428275823593, rolling accuracy: 95.31250762939453
# TRAINING - Step: 70, loss: 0.016715053468942642, rolling accuracy: 95.08928680419922
# TRAINING - Step: 80, loss: 0.020362380892038345, rolling accuracy: 95.703125
# TRAINING - Step: 90, loss: 0.009080270305275917, rolling accuracy: 95.83333587646484
# TRAINING - Step: 100, loss: 0.012351947836577892, rolling accuracy: 95.625
# TRAINING - Step: 110, loss: 0.01946185901761055, rolling accuracy: 95.17044830322266
# TRAINING - Step: 120, loss: 0.0566469207406044, rolling accuracy: 95.31250762939453
# TRAINING - Step: 130, loss: 0.011661456897854805, rolling accuracy: 95.19230651855469
# TRAINING - Step: 140, loss: 0.036114953458309174, rolling accuracy: 94.86607360839844
# TRAINING - Step: 150, loss: 0.018944475799798965, rolling accuracy: 94.79167175292969
# TRAINING - Step: 160, loss: 0.014238479547202587, rolling accuracy: 94.7265625
# TESTING - Loss: 0.026509417220950127, Accuracy: 98.32316589355469
# +++ FEDERATED MODEL 0, EPOCH: 4 +++++++++
# TRAINING - Step: 10, loss: 0.12559320032596588, rolling accuracy: 93.75
# TRAINING - Step: 20, loss: 0.015072403475642204, rolling accuracy: 95.3125
# TRAINING - Step: 30, loss: 0.027907654643058777, rolling accuracy: 94.79167175292969
# TRAINING - Step: 40, loss: 0.03358973562717438, rolling accuracy: 92.96875
# TRAINING - Step: 50, loss: 0.00811876729130745, rolling accuracy: 93.75
# TRAINING - Step: 60, loss: 0.00802704505622387, rolling accuracy: 94.79167175292969
# TRAINING - Step: 70, loss: 0.015077120624482632, rolling accuracy: 95.53571319580078
# TRAINING - Step: 80, loss: 0.07080896198749542, rolling accuracy: 95.3125
# TRAINING - Step: 90, loss: 0.011457400396466255, rolling accuracy: 95.1388931274414
# TRAINING - Step: 100, loss: 0.00916589330881834, rolling accuracy: 95.0
# TRAINING - Step: 110, loss: 0.04465518891811371, rolling accuracy: 94.88636016845703
# TRAINING - Step: 120, loss: 0.127092644572258, rolling accuracy: 94.79167175292969
# TRAINING - Step: 130, loss: 0.004293479491025209, rolling accuracy: 95.19230651855469
# TRAINING - Step: 140, loss: 0.012415893375873566, rolling accuracy: 95.08928680419922
# TRAINING - Step: 150, loss: 0.020268872380256653, rolling accuracy: 95.20833587646484
# TRAINING - Step: 160, loss: 0.06175714731216431, rolling accuracy: 94.921875
# +++ FEDERATED MODEL 1, EPOCH: 4 +++++++++
# TRAINING - Step: 10, loss: 0.010696601122617722, rolling accuracy: 96.875
# TRAINING - Step: 20, loss: 0.007170370779931545, rolling accuracy: 98.4375
# TRAINING - Step: 30, loss: 0.013824542053043842, rolling accuracy: 96.87500762939453
# TRAINING - Step: 40, loss: 0.013747716322541237, rolling accuracy: 96.875
# TRAINING - Step: 50, loss: 0.011343436315655708, rolling accuracy: 97.5
# TRAINING - Step: 60, loss: 0.01327244658023119, rolling accuracy: 96.87500762939453
# TRAINING - Step: 70, loss: 0.01031456794589758, rolling accuracy: 96.42857360839844
# TRAINING - Step: 80, loss: 0.021488294005393982, rolling accuracy: 96.09375
# TRAINING - Step: 90, loss: 0.009495312348008156, rolling accuracy: 96.52777862548828
# TRAINING - Step: 100, loss: 0.0029301729518920183, rolling accuracy: 96.875
# TRAINING - Step: 110, loss: 0.16515004634857178, rolling accuracy: 96.59090423583984
# TRAINING - Step: 120, loss: 0.009034544229507446, rolling accuracy: 96.87500762939453
# TRAINING - Step: 130, loss: 0.11498663574457169, rolling accuracy: 96.39423370361328
# TRAINING - Step: 140, loss: 0.015661710873246193, rolling accuracy: 96.20536041259766
# TRAINING - Step: 150, loss: 0.01170087605714798, rolling accuracy: 96.25
# TRAINING - Step: 160, loss: 0.009939972311258316, rolling accuracy: 96.2890625
# +++ FEDERATED MODEL 2, EPOCH: 4 +++++++++
# TRAINING - Step: 10, loss: 0.01084922906011343, rolling accuracy: 96.875
# TRAINING - Step: 20, loss: 0.013871652074158192, rolling accuracy: 96.875
# TRAINING - Step: 30, loss: 0.008785635232925415, rolling accuracy: 97.91667175292969
# TRAINING - Step: 40, loss: 0.020528336986899376, rolling accuracy: 97.65625
# TRAINING - Step: 50, loss: 0.009403887204825878, rolling accuracy: 98.125
# TRAINING - Step: 60, loss: 0.04552377387881279, rolling accuracy: 97.39583587646484
# TRAINING - Step: 70, loss: 0.0691891759634018, rolling accuracy: 96.875
# TRAINING - Step: 80, loss: 0.01636088453233242, rolling accuracy: 96.875
# TRAINING - Step: 90, loss: 0.045296356081962585, rolling accuracy: 96.18055725097656
# TRAINING - Step: 100, loss: 0.02256431244313717, rolling accuracy: 95.9375
# TRAINING - Step: 110, loss: 0.009952150285243988, rolling accuracy: 95.73863220214844
# TRAINING - Step: 120, loss: 0.027670567855238914, rolling accuracy: 95.57292175292969
# TRAINING - Step: 130, loss: 0.03514351695775986, rolling accuracy: 95.43269348144531
# TRAINING - Step: 140, loss: 0.023737870156764984, rolling accuracy: 95.08928680419922
# TRAINING - Step: 150, loss: 0.004931666888296604, rolling accuracy: 95.41667175292969
# TRAINING - Step: 160, loss: 0.010418273508548737, rolling accuracy: 95.5078125
# +++ FEDERATED MODEL 3, EPOCH: 4 +++++++++
# TRAINING - Step: 10, loss: 0.0021096826530992985, rolling accuracy: 100.0
# TRAINING - Step: 20, loss: 0.01874082162976265, rolling accuracy: 96.875
# TRAINING - Step: 30, loss: 0.0237104594707489, rolling accuracy: 97.91667175292969
# TRAINING - Step: 40, loss: 0.028835278004407883, rolling accuracy: 96.875
# TRAINING - Step: 50, loss: 0.009366988204419613, rolling accuracy: 96.875
# TRAINING - Step: 60, loss: 0.031390730291604996, rolling accuracy: 96.87500762939453
# TRAINING - Step: 70, loss: 0.01211992185562849, rolling accuracy: 96.875
# TRAINING - Step: 80, loss: 0.012598562985658646, rolling accuracy: 97.265625
# TRAINING - Step: 90, loss: 0.015924151986837387, rolling accuracy: 96.52777862548828
# TRAINING - Step: 100, loss: 0.01397409476339817, rolling accuracy: 96.25
# TRAINING - Step: 110, loss: 0.02146395854651928, rolling accuracy: 96.59090423583984
# TRAINING - Step: 120, loss: 0.024993330240249634, rolling accuracy: 96.09375762939453
# TRAINING - Step: 130, loss: 0.0010271191131323576, rolling accuracy: 96.39423370361328
# TRAINING - Step: 140, loss: 0.013720895163714886, rolling accuracy: 96.42857360839844
# TRAINING - Step: 150, loss: 0.014987349510192871, rolling accuracy: 96.45833587646484
# TRAINING - Step: 160, loss: 0.017653372138738632, rolling accuracy: 96.2890625
# TESTING - Loss: 0.011974264867603779, Accuracy: 98.32316589355469
# +++ FEDERATED MODEL 0, EPOCH: 5 +++++++++
# TRAINING - Step: 10, loss: 0.018208066001534462, rolling accuracy: 87.5
# TRAINING - Step: 20, loss: 0.01218805555254221, rolling accuracy: 92.1875
# TRAINING - Step: 30, loss: 0.046747758984565735, rolling accuracy: 92.70833587646484
# TRAINING - Step: 40, loss: 0.023122141137719154, rolling accuracy: 92.1875
# TRAINING - Step: 50, loss: 0.030185390263795853, rolling accuracy: 93.125
# TRAINING - Step: 60, loss: 0.004201808013021946, rolling accuracy: 94.27083587646484
# TRAINING - Step: 70, loss: 0.003522035665810108, rolling accuracy: 95.08928680419922
# TRAINING - Step: 80, loss: 0.015201712027192116, rolling accuracy: 95.3125
# TRAINING - Step: 90, loss: 0.016228383406996727, rolling accuracy: 95.1388931274414
# TRAINING - Step: 100, loss: 0.008024705573916435, rolling accuracy: 95.3125
# TRAINING - Step: 110, loss: 0.014173939824104309, rolling accuracy: 95.73863220214844
# TRAINING - Step: 120, loss: 0.023550232872366905, rolling accuracy: 95.05208587646484
# TRAINING - Step: 130, loss: 0.00884944386780262, rolling accuracy: 95.19230651855469
# TRAINING - Step: 140, loss: 0.0024753082543611526, rolling accuracy: 95.53571319580078
# TRAINING - Step: 150, loss: 0.01019451767206192, rolling accuracy: 95.41667175292969
# TRAINING - Step: 160, loss: 0.006617364473640919, rolling accuracy: 95.703125
# +++ FEDERATED MODEL 1, EPOCH: 5 +++++++++
# TRAINING - Step: 10, loss: 0.16000239551067352, rolling accuracy: 93.75
# TRAINING - Step: 20, loss: 0.012015755288302898, rolling accuracy: 93.75
# TRAINING - Step: 30, loss: 0.03225502744317055, rolling accuracy: 90.62500762939453
# TRAINING - Step: 40, loss: 0.018699517473578453, rolling accuracy: 92.1875
# TRAINING - Step: 50, loss: 0.008409393951296806, rolling accuracy: 93.125
# TRAINING - Step: 60, loss: 0.0092969611287117, rolling accuracy: 93.22917175292969
# TRAINING - Step: 70, loss: 0.01443985290825367, rolling accuracy: 93.75
# TRAINING - Step: 80, loss: 0.007210821844637394, rolling accuracy: 94.53125
# TRAINING - Step: 90, loss: 0.02775457128882408, rolling accuracy: 93.75
# TRAINING - Step: 100, loss: 0.006520894821733236, rolling accuracy: 94.0625
# TRAINING - Step: 110, loss: 0.015207192860543728, rolling accuracy: 94.03408813476562
# TRAINING - Step: 120, loss: 0.024820275604724884, rolling accuracy: 94.53125762939453
# TRAINING - Step: 130, loss: 0.008358949795365334, rolling accuracy: 94.71154022216797
# TRAINING - Step: 140, loss: 0.017176810652017593, rolling accuracy: 94.64286041259766
# TRAINING - Step: 150, loss: 0.0016563467215746641, rolling accuracy: 95.0
# TRAINING - Step: 160, loss: 0.006303253583610058, rolling accuracy: 95.1171875
# +++ FEDERATED MODEL 2, EPOCH: 5 +++++++++
# TRAINING - Step: 10, loss: 0.015323950909078121, rolling accuracy: 96.875
# TRAINING - Step: 20, loss: 0.008080593310296535, rolling accuracy: 95.3125
# TRAINING - Step: 30, loss: 0.01170773059129715, rolling accuracy: 95.83333587646484
# TRAINING - Step: 40, loss: 0.08915302902460098, rolling accuracy: 96.09375
# TRAINING - Step: 50, loss: 0.004212895408272743, rolling accuracy: 96.875
# TRAINING - Step: 60, loss: 0.0046964967623353004, rolling accuracy: 96.87500762939453
# TRAINING - Step: 70, loss: 0.05512656271457672, rolling accuracy: 95.08928680419922
# TRAINING - Step: 80, loss: 0.01751439832150936, rolling accuracy: 94.921875
# TRAINING - Step: 90, loss: 0.18532055616378784, rolling accuracy: 95.1388931274414
# TRAINING - Step: 100, loss: 0.011924189515411854, rolling accuracy: 95.625
# TRAINING - Step: 110, loss: 0.027639111503958702, rolling accuracy: 94.31817626953125
# TRAINING - Step: 120, loss: 0.01886804774403572, rolling accuracy: 94.53125762939453
# TRAINING - Step: 130, loss: 0.01733272522687912, rolling accuracy: 94.47115325927734
# TRAINING - Step: 140, loss: 0.019774161279201508, rolling accuracy: 94.19642639160156
# TRAINING - Step: 150, loss: 0.022301238030195236, rolling accuracy: 94.16667175292969
# TRAINING - Step: 160, loss: 0.0027332142926752567, rolling accuracy: 94.53125
# +++ FEDERATED MODEL 3, EPOCH: 5 +++++++++
# TRAINING - Step: 10, loss: 0.005727320909500122, rolling accuracy: 96.875
# TRAINING - Step: 20, loss: 0.137340247631073, rolling accuracy: 95.3125
# TRAINING - Step: 30, loss: 0.021540846675634384, rolling accuracy: 96.87500762939453
# TRAINING - Step: 40, loss: 0.01501383539289236, rolling accuracy: 96.875
# TRAINING - Step: 50, loss: 0.003858495270833373, rolling accuracy: 97.5
# TRAINING - Step: 60, loss: 0.015361933968961239, rolling accuracy: 97.39583587646484
# TRAINING - Step: 70, loss: 0.0067728920839726925, rolling accuracy: 97.32142639160156
# TRAINING - Step: 80, loss: 0.03948212414979935, rolling accuracy: 96.875
# TRAINING - Step: 90, loss: 0.025766827166080475, rolling accuracy: 95.48611450195312
# TRAINING - Step: 100, loss: 0.013763063587248325, rolling accuracy: 95.625
# TRAINING - Step: 110, loss: 0.005113987717777491, rolling accuracy: 96.0227279663086
# TRAINING - Step: 120, loss: 0.015254246070981026, rolling accuracy: 95.83333587646484
# TRAINING - Step: 130, loss: 0.013299863785505295, rolling accuracy: 95.67308044433594
# TRAINING - Step: 140, loss: 0.019189249724149704, rolling accuracy: 95.75892639160156
# TRAINING - Step: 150, loss: 0.0018882444128394127, rolling accuracy: 96.04167175292969
# TRAINING - Step: 160, loss: 0.009908735752105713, rolling accuracy: 96.09375
# TESTING - Loss: 0.01934647746384144, Accuracy: 98.85670471191406
# Early return: SUCCESS

# %%
federated_model = torchvision.models.resnet18(pretrained=False, num_classes=1)
federated_test_loader = torch.utils.data.DataLoader(test_set, batch_size=32, shuffle=False, num_workers=0)
client_models = [torchvision.models.resnet18(pretrained=False, num_classes=1) for _ in range(number_of_clients)]

train_loader_split_no_augment = prepare_train_data(train_set, number_of_clients, augment_data=False, full_data_on_each_client=False)

run_federated_training(federated_model, client_models, train_loader_split_no_augment)

train_loader_split_no_augment = None
# Out:
# +++ FEDERATED MODEL 0, EPOCH: 1 +++++++++
# C:\Users\Donat\anaconda3\lib\site-packages\torch\nn\functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  ..\c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# TRAINING - Step: 10, loss: 0.05574168264865875, rolling accuracy: 84.375
# TRAINING - Step: 20, loss: 0.07420063018798828, rolling accuracy: 82.8125
# TRAINING - Step: 30, loss: 0.06762982159852982, rolling accuracy: 84.37500762939453
# TRAINING - Step: 40, loss: 0.018281031399965286, rolling accuracy: 88.28125
# +++ FEDERATED MODEL 1, EPOCH: 1 +++++++++
# TRAINING - Step: 10, loss: 0.16669614613056183, rolling accuracy: 84.375
# TRAINING - Step: 20, loss: 0.02745596319437027, rolling accuracy: 90.625
# TRAINING - Step: 30, loss: 0.12275668978691101, rolling accuracy: 88.54167175292969
# TRAINING - Step: 40, loss: 0.1068161129951477, rolling accuracy: 89.84375
# +++ FEDERATED MODEL 2, EPOCH: 1 +++++++++
# TRAINING - Step: 10, loss: 0.07781316339969635, rolling accuracy: 53.125
# TRAINING - Step: 20, loss: 0.045210178941488266, rolling accuracy: 73.4375
# TRAINING - Step: 30, loss: 0.01338769868016243, rolling accuracy: 80.20833587646484
# TRAINING - Step: 40, loss: 0.060781337320804596, rolling accuracy: 82.8125
# +++ FEDERATED MODEL 3, EPOCH: 1 +++++++++
# TRAINING - Step: 10, loss: 0.03894130885601044, rolling accuracy: 96.875
# TRAINING - Step: 20, loss: 0.06749524176120758, rolling accuracy: 95.3125
# TRAINING - Step: 30, loss: 0.05939943343400955, rolling accuracy: 88.54167175292969
# TRAINING - Step: 40, loss: 0.02179909497499466, rolling accuracy: 89.84375
# TESTING - Loss: 0.2383297085762024, Accuracy: 91.15853118896484
# +++ FEDERATED MODEL 0, EPOCH: 2 +++++++++
# TRAINING - Step: 10, loss: 0.03273632377386093, rolling accuracy: 93.75
# TRAINING - Step: 20, loss: 0.033297665417194366, rolling accuracy: 96.875
# TRAINING - Step: 30, loss: 0.028356535360217094, rolling accuracy: 94.79167175292969
# TRAINING - Step: 40, loss: 0.17173705995082855, rolling accuracy: 93.75
# +++ FEDERATED MODEL 1, EPOCH: 2 +++++++++
# TRAINING - Step: 10, loss: 0.050148673355579376, rolling accuracy: 81.25
# TRAINING - Step: 20, loss: 0.051270075142383575, rolling accuracy: 89.0625
# TRAINING - Step: 30, loss: 0.02908322773873806, rolling accuracy: 88.54167175292969
# TRAINING - Step: 40, loss: 0.0900934487581253, rolling accuracy: 85.9375
# +++ FEDERATED MODEL 2, EPOCH: 2 +++++++++
# TRAINING - Step: 10, loss: 0.023793909698724747, rolling accuracy: 93.75
# TRAINING - Step: 20, loss: 0.021244186908006668, rolling accuracy: 93.75
# TRAINING - Step: 30, loss: 0.04341227561235428, rolling accuracy: 91.66667175292969
# TRAINING - Step: 40, loss: 0.046139463782310486, rolling accuracy: 89.84375
# +++ FEDERATED MODEL 3, EPOCH: 2 +++++++++
# TRAINING - Step: 10, loss: 0.03685972839593887, rolling accuracy: 90.625
# TRAINING - Step: 20, loss: 0.014895107597112656, rolling accuracy: 92.1875
# TRAINING - Step: 30, loss: 0.10250882059335709, rolling accuracy: 89.58333587646484
# TRAINING - Step: 40, loss: 0.1703641712665558, rolling accuracy: 89.0625
# TESTING - Loss: 0.046254877001047134, Accuracy: 94.43597412109375
# +++ FEDERATED MODEL 0, EPOCH: 3 +++++++++
# TRAINING - Step: 10, loss: 0.047693584114313126, rolling accuracy: 84.375
# TRAINING - Step: 20, loss: 0.02960524894297123, rolling accuracy: 85.9375
# TRAINING - Step: 30, loss: 0.014063115231692791, rolling accuracy: 90.62500762939453
# TRAINING - Step: 40, loss: 0.0273626446723938, rolling accuracy: 91.40625
# +++ FEDERATED MODEL 1, EPOCH: 3 +++++++++
# TRAINING - Step: 10, loss: 0.06900067627429962, rolling accuracy: 84.375
# TRAINING - Step: 20, loss: 0.1014150083065033, rolling accuracy: 87.5
# TRAINING - Step: 30, loss: 0.017622990533709526, rolling accuracy: 88.54167175292969
# TRAINING - Step: 40, loss: 0.016972005367279053, rolling accuracy: 90.625
# +++ FEDERATED MODEL 2, EPOCH: 3 +++++++++
# TRAINING - Step: 10, loss: 0.1199062317609787, rolling accuracy: 87.5
# TRAINING - Step: 20, loss: 0.03650953620672226, rolling accuracy: 89.0625
# TRAINING - Step: 30, loss: 0.009903938509523869, rolling accuracy: 92.70833587646484
# TRAINING - Step: 40, loss: 0.04510148987174034, rolling accuracy: 92.96875
# +++ FEDERATED MODEL 3, EPOCH: 3 +++++++++
# TRAINING - Step: 10, loss: 0.05102289468050003, rolling accuracy: 81.25
# TRAINING - Step: 20, loss: 0.02515247091650963, rolling accuracy: 84.375
# TRAINING - Step: 30, loss: 0.018483197316527367, rolling accuracy: 87.50000762939453
# TRAINING - Step: 40, loss: 0.019605407491326332, rolling accuracy: 89.0625
# TESTING - Loss: 0.030722416937351227, Accuracy: 94.8932876586914
# +++ FEDERATED MODEL 0, EPOCH: 4 +++++++++
# TRAINING - Step: 10, loss: 0.005100953858345747, rolling accuracy: 100.0
# TRAINING - Step: 20, loss: 0.04082475230097771, rolling accuracy: 96.875
# TRAINING - Step: 30, loss: 0.018999233841896057, rolling accuracy: 93.75000762939453
# TRAINING - Step: 40, loss: 0.009438744746148586, rolling accuracy: 95.3125
# +++ FEDERATED MODEL 1, EPOCH: 4 +++++++++
# TRAINING - Step: 10, loss: 0.019279107451438904, rolling accuracy: 93.75
# TRAINING - Step: 20, loss: 0.022090241312980652, rolling accuracy: 93.75
# TRAINING - Step: 30, loss: 0.010265301913022995, rolling accuracy: 95.83333587646484
# TRAINING - Step: 40, loss: 0.1351550817489624, rolling accuracy: 94.53125
# +++ FEDERATED MODEL 2, EPOCH: 4 +++++++++
# TRAINING - Step: 10, loss: 0.04772709310054779, rolling accuracy: 93.75
# TRAINING - Step: 20, loss: 0.060904957354068756, rolling accuracy: 95.3125
# TRAINING - Step: 30, loss: 0.026542220264673233, rolling accuracy: 94.79167175292969
# TRAINING - Step: 40, loss: 0.013927634805440903, rolling accuracy: 96.09375
# +++ FEDERATED MODEL 3, EPOCH: 4 +++++++++
# TRAINING - Step: 10, loss: 0.042147196829319, rolling accuracy: 96.875
# TRAINING - Step: 20, loss: 0.007362471893429756, rolling accuracy: 96.875
# TRAINING - Step: 30, loss: 0.02689807116985321, rolling accuracy: 94.79167175292969
# TRAINING - Step: 40, loss: 0.02060506120324135, rolling accuracy: 95.3125
# TESTING - Loss: 0.01900422014296055, Accuracy: 96.41767883300781
# +++ FEDERATED MODEL 0, EPOCH: 5 +++++++++
# TRAINING - Step: 10, loss: 0.011584402993321419, rolling accuracy: 96.875
# TRAINING - Step: 20, loss: 0.024721069261431694, rolling accuracy: 98.4375
# TRAINING - Step: 30, loss: 0.08406899124383926, rolling accuracy: 91.66667175292969
# TRAINING - Step: 40, loss: 0.025032367557287216, rolling accuracy: 92.1875
# +++ FEDERATED MODEL 1, EPOCH: 5 +++++++++
# TRAINING - Step: 10, loss: 0.04184544458985329, rolling accuracy: 90.625
# TRAINING - Step: 20, loss: 0.042207881808280945, rolling accuracy: 92.1875
# TRAINING - Step: 30, loss: 0.013600962236523628, rolling accuracy: 93.75000762939453
# TRAINING - Step: 40, loss: 0.006925258785486221, rolling accuracy: 94.53125
# +++ FEDERATED MODEL 2, EPOCH: 5 +++++++++
# TRAINING - Step: 10, loss: 0.038058385252952576, rolling accuracy: 93.75
# TRAINING - Step: 20, loss: 0.07481997460126877, rolling accuracy: 90.625
# TRAINING - Step: 30, loss: 0.009085157886147499, rolling accuracy: 92.70833587646484
# TRAINING - Step: 40, loss: 0.10373404622077942, rolling accuracy: 93.75
# +++ FEDERATED MODEL 3, EPOCH: 5 +++++++++
# TRAINING - Step: 10, loss: 0.14349967241287231, rolling accuracy: 93.75
# TRAINING - Step: 20, loss: 0.04393457993865013, rolling accuracy: 93.75
# TRAINING - Step: 30, loss: 0.042748115956783295, rolling accuracy: 94.79167175292969
# TRAINING - Step: 40, loss: 0.030942384153604507, rolling accuracy: 93.75
# TESTING - Loss: 0.0176266897469759, Accuracy: 95.1219482421875
# +++ FEDERATED MODEL 0, EPOCH: 6 +++++++++
# TRAINING - Step: 10, loss: 0.006324331276118755, rolling accuracy: 100.0
# TRAINING - Step: 20, loss: 0.16508670151233673, rolling accuracy: 92.1875
# TRAINING - Step: 30, loss: 0.026065679267048836, rolling accuracy: 91.66667175292969
# TRAINING - Step: 40, loss: 0.01151676382869482, rolling accuracy: 92.96875
# +++ FEDERATED MODEL 1, EPOCH: 6 +++++++++
# TRAINING - Step: 10, loss: 0.04205448180437088, rolling accuracy: 78.125
# TRAINING - Step: 20, loss: 0.0073371771723032, rolling accuracy: 87.5
# TRAINING - Step: 30, loss: 0.015852011740207672, rolling accuracy: 89.58333587646484
# TRAINING - Step: 40, loss: 0.0422012060880661, rolling accuracy: 91.40625
# +++ FEDERATED MODEL 2, EPOCH: 6 +++++++++
# TRAINING - Step: 10, loss: 0.00981550756841898, rolling accuracy: 96.875
# TRAINING - Step: 20, loss: 0.0369829423725605, rolling accuracy: 96.875
# TRAINING - Step: 30, loss: 0.04230094328522682, rolling accuracy: 92.70833587646484
# TRAINING - Step: 40, loss: 0.004730082582682371, rolling accuracy: 94.53125
# +++ FEDERATED MODEL 3, EPOCH: 6 +++++++++
# TRAINING - Step: 10, loss: 0.0034376138355582952, rolling accuracy: 100.0
# TRAINING - Step: 20, loss: 0.06453358381986618, rolling accuracy: 90.625
# TRAINING - Step: 30, loss: 0.015329144895076752, rolling accuracy: 92.70833587646484
# TRAINING - Step: 40, loss: 0.00958099402487278, rolling accuracy: 93.75
# TESTING - Loss: 0.015391766093671322, Accuracy: 96.18901824951172
# +++ FEDERATED MODEL 0, EPOCH: 7 +++++++++
# TRAINING - Step: 10, loss: 0.016877103596925735, rolling accuracy: 93.75
# TRAINING - Step: 20, loss: 0.013673205859959126, rolling accuracy: 93.75
# TRAINING - Step: 30, loss: 0.0312855988740921, rolling accuracy: 92.70833587646484
# TRAINING - Step: 40, loss: 0.021787084639072418, rolling accuracy: 92.96875
# +++ FEDERATED MODEL 1, EPOCH: 7 +++++++++
# TRAINING - Step: 10, loss: 0.005191548261791468, rolling accuracy: 100.0
# TRAINING - Step: 20, loss: 0.00571422278881073, rolling accuracy: 100.0
# TRAINING - Step: 30, loss: 0.01611458510160446, rolling accuracy: 100.00000762939453
# TRAINING - Step: 40, loss: 0.03386962413787842, rolling accuracy: 96.875
# +++ FEDERATED MODEL 2, EPOCH: 7 +++++++++
# TRAINING - Step: 10, loss: 0.005083645228296518, rolling accuracy: 100.0
# TRAINING - Step: 20, loss: 0.02704208716750145, rolling accuracy: 95.3125
# TRAINING - Step: 30, loss: 0.013414964079856873, rolling accuracy: 95.83333587646484
# TRAINING - Step: 40, loss: 0.010386976413428783, rolling accuracy: 95.3125
# +++ FEDERATED MODEL 3, EPOCH: 7 +++++++++
# TRAINING - Step: 10, loss: 0.022958999499678612, rolling accuracy: 93.75
# TRAINING - Step: 20, loss: 0.06908372044563293, rolling accuracy: 95.3125
# TRAINING - Step: 30, loss: 0.020658046007156372, rolling accuracy: 94.79167175292969
# TRAINING - Step: 40, loss: 0.009920947253704071, rolling accuracy: 95.3125
# TESTING - Loss: 0.014285818673670292, Accuracy: 95.19816589355469
# +++ FEDERATED MODEL 0, EPOCH: 8 +++++++++
# TRAINING - Step: 10, loss: 0.0031688218005001545, rolling accuracy: 100.0
# TRAINING - Step: 20, loss: 0.023437509313225746, rolling accuracy: 96.875
# TRAINING - Step: 30, loss: 0.007471838966012001, rolling accuracy: 96.87500762939453
# TRAINING - Step: 40, loss: 0.058812279254198074, rolling accuracy: 96.09375
# +++ FEDERATED MODEL 1, EPOCH: 8 +++++++++
# TRAINING - Step: 10, loss: 0.013027300126850605, rolling accuracy: 96.875
# TRAINING - Step: 20, loss: 0.031233230605721474, rolling accuracy: 87.5
# TRAINING - Step: 30, loss: 0.016035769134759903, rolling accuracy: 90.62500762939453
# TRAINING - Step: 40, loss: 0.021836470812559128, rolling accuracy: 90.625
# +++ FEDERATED MODEL 2, EPOCH: 8 +++++++++
# TRAINING - Step: 10, loss: 0.01863531395792961, rolling accuracy: 90.625
# TRAINING - Step: 20, loss: 0.1715996116399765, rolling accuracy: 92.1875
# TRAINING - Step: 30, loss: 0.01130281575024128, rolling accuracy: 94.79167175292969
# TRAINING - Step: 40, loss: 0.008909113705158234, rolling accuracy: 96.09375
# +++ FEDERATED MODEL 3, EPOCH: 8 +++++++++
# TRAINING - Step: 10, loss: 0.009361609816551208, rolling accuracy: 100.0
# TRAINING - Step: 20, loss: 0.010770256631076336, rolling accuracy: 96.875
# TRAINING - Step: 30, loss: 0.03054681047797203, rolling accuracy: 94.79167175292969
# TRAINING - Step: 40, loss: 0.007904755882918835, rolling accuracy: 95.3125
# TESTING - Loss: 0.00988464243710041, Accuracy: 97.63719177246094
# Early return: SUCCESS

# %%
federated_model = torchvision.models.resnet18(pretrained=False, num_classes=1)
federated_test_loader = torch.utils.data.DataLoader(test_set, batch_size=32, shuffle=False, num_workers=0)
client_models = [torchvision.models.resnet18(pretrained=False, num_classes=1) for _ in range(number_of_clients)]

train_loader_split_augment = prepare_train_data(train_set, number_of_clients, augment_data=True, full_data_on_each_client=False)

run_federated_training(federated_model, client_models, train_loader_split_augment)

train_loader_split_augment = None
# Out:
# +++ FEDERATED MODEL 0, EPOCH: 1 +++++++++
# TRAINING - Step: 10, loss: 0.19133463501930237, rolling accuracy: 46.875
# TRAINING - Step: 20, loss: 0.08497636020183563, rolling accuracy: 56.25
# TRAINING - Step: 30, loss: 0.07978109270334244, rolling accuracy: 62.500003814697266
# TRAINING - Step: 40, loss: 0.07718903571367264, rolling accuracy: 68.75
# +++ FEDERATED MODEL 1, EPOCH: 1 +++++++++
# TRAINING - Step: 10, loss: 0.12506169080734253, rolling accuracy: 56.25
# TRAINING - Step: 20, loss: 0.14163631200790405, rolling accuracy: 70.3125
# TRAINING - Step: 30, loss: 0.11963967233896255, rolling accuracy: 68.75
# TRAINING - Step: 40, loss: 0.08996886759996414, rolling accuracy: 71.875
# +++ FEDERATED MODEL 2, EPOCH: 1 +++++++++
# TRAINING - Step: 10, loss: 0.14307551085948944, rolling accuracy: 81.25
# TRAINING - Step: 20, loss: 0.0527038648724556, rolling accuracy: 82.8125
# TRAINING - Step: 30, loss: 0.12159614264965057, rolling accuracy: 71.875
# TRAINING - Step: 40, loss: 0.10530561208724976, rolling accuracy: 67.96875
# +++ FEDERATED MODEL 3, EPOCH: 1 +++++++++
# TRAINING - Step: 10, loss: 0.061162400990724564, rolling accuracy: 62.5
# TRAINING - Step: 20, loss: 0.13157424330711365, rolling accuracy: 73.4375
# TRAINING - Step: 30, loss: 0.1678156703710556, rolling accuracy: 71.875
# TRAINING - Step: 40, loss: 0.1046227291226387, rolling accuracy: 71.09375
# TESTING - Loss: 0.1923913210630417, Accuracy: 91.15853118896484
# +++ FEDERATED MODEL 0, EPOCH: 2 +++++++++
# TRAINING - Step: 10, loss: 0.07538414746522903, rolling accuracy: 65.625
# TRAINING - Step: 20, loss: 0.14538607001304626, rolling accuracy: 45.3125
# TRAINING - Step: 30, loss: 0.23346218466758728, rolling accuracy: 56.250003814697266
# TRAINING - Step: 40, loss: 0.06368598341941833, rolling accuracy: 61.71875
# +++ FEDERATED MODEL 1, EPOCH: 2 +++++++++
# TRAINING - Step: 10, loss: 0.38303279876708984, rolling accuracy: 75.0
# TRAINING - Step: 20, loss: 0.1298874467611313, rolling accuracy: 78.125
# TRAINING - Step: 30, loss: 0.06617709249258041, rolling accuracy: 78.12500762939453
# TRAINING - Step: 40, loss: 0.11797972023487091, rolling accuracy: 70.3125
# +++ FEDERATED MODEL 2, EPOCH: 2 +++++++++
# TRAINING - Step: 10, loss: 0.16842328011989594, rolling accuracy: 81.25
# TRAINING - Step: 20, loss: 0.08458064496517181, rolling accuracy: 81.25
# TRAINING - Step: 30, loss: 0.10861154645681381, rolling accuracy: 78.12500762939453
# TRAINING - Step: 40, loss: 0.08916234970092773, rolling accuracy: 80.46875
# +++ FEDERATED MODEL 3, EPOCH: 2 +++++++++
# TRAINING - Step: 10, loss: 0.09217165410518646, rolling accuracy: 62.5
# TRAINING - Step: 20, loss: 0.12945136427879333, rolling accuracy: 65.625
# TRAINING - Step: 30, loss: 0.10304298996925354, rolling accuracy: 71.875
# TRAINING - Step: 40, loss: 0.08000568300485611, rolling accuracy: 70.3125
# TESTING - Loss: 0.15703898668289185, Accuracy: 91.15853118896484
# +++ FEDERATED MODEL 0, EPOCH: 3 +++++++++
# TRAINING - Step: 10, loss: 0.17491888999938965, rolling accuracy: 59.375
# TRAINING - Step: 20, loss: 0.1058291643857956, rolling accuracy: 67.1875
# TRAINING - Step: 30, loss: 0.19475427269935608, rolling accuracy: 72.91667175292969
# TRAINING - Step: 40, loss: 0.1783681958913803, rolling accuracy: 76.5625
# +++ FEDERATED MODEL 1, EPOCH: 3 +++++++++
# TRAINING - Step: 10, loss: 0.08761729300022125, rolling accuracy: 62.5
# TRAINING - Step: 20, loss: 0.10693707317113876, rolling accuracy: 56.25
# TRAINING - Step: 30, loss: 0.09526452422142029, rolling accuracy: 60.41666793823242
# TRAINING - Step: 40, loss: 0.10211822390556335, rolling accuracy: 66.40625
# +++ FEDERATED MODEL 2, EPOCH: 3 +++++++++
# TRAINING - Step: 10, loss: 0.23212769627571106, rolling accuracy: 84.375
# TRAINING - Step: 20, loss: 0.1784241497516632, rolling accuracy: 70.3125
# TRAINING - Step: 30, loss: 0.10554152727127075, rolling accuracy: 69.79167175292969
# TRAINING - Step: 40, loss: 0.08417132496833801, rolling accuracy: 71.875
# +++ FEDERATED MODEL 3, EPOCH: 3 +++++++++
# TRAINING - Step: 10, loss: 0.14647993445396423, rolling accuracy: 56.25
# TRAINING - Step: 20, loss: 0.13857781887054443, rolling accuracy: 67.1875
# TRAINING - Step: 30, loss: 0.11093917489051819, rolling accuracy: 65.625
# TRAINING - Step: 40, loss: 0.13648203015327454, rolling accuracy: 66.40625
# TESTING - Loss: 0.13739462196826935, Accuracy: 17.530487060546875
# +++ FEDERATED MODEL 0, EPOCH: 4 +++++++++
# TRAINING - Step: 10, loss: 0.08200579881668091, rolling accuracy: 59.375
# TRAINING - Step: 20, loss: 0.13542112708091736, rolling accuracy: 73.4375
# TRAINING - Step: 30, loss: 0.12816476821899414, rolling accuracy: 59.375003814697266
# TRAINING - Step: 40, loss: 0.10142525285482407, rolling accuracy: 64.0625
# +++ FEDERATED MODEL 1, EPOCH: 4 +++++++++
# TRAINING - Step: 10, loss: 0.09960056841373444, rolling accuracy: 43.75
# TRAINING - Step: 20, loss: 0.05633067712187767, rolling accuracy: 57.8125
# TRAINING - Step: 30, loss: 0.18576273322105408, rolling accuracy: 65.625
# TRAINING - Step: 40, loss: 0.11117906123399734, rolling accuracy: 72.65625
# +++ FEDERATED MODEL 2, EPOCH: 4 +++++++++
# TRAINING - Step: 10, loss: 0.04577585682272911, rolling accuracy: 81.25
# TRAINING - Step: 20, loss: 0.16177546977996826, rolling accuracy: 64.0625
# TRAINING - Step: 30, loss: 0.11763482540845871, rolling accuracy: 63.54167175292969
# TRAINING - Step: 40, loss: 0.10125643759965897, rolling accuracy: 69.53125
# +++ FEDERATED MODEL 3, EPOCH: 4 +++++++++
# TRAINING - Step: 10, loss: 0.11835334450006485, rolling accuracy: 46.875
# TRAINING - Step: 20, loss: 0.08902842551469803, rolling accuracy: 62.5
# TRAINING - Step: 30, loss: 0.061457596719264984, rolling accuracy: 65.625
# TRAINING - Step: 40, loss: 0.17373304069042206, rolling accuracy: 68.75
# TESTING - Loss: 0.1276150941848755, Accuracy: 70.2743911743164
# +++ FEDERATED MODEL 0, EPOCH: 5 +++++++++
# TRAINING - Step: 10, loss: 0.10282851755619049, rolling accuracy: 46.875
# TRAINING - Step: 20, loss: 0.08000634610652924, rolling accuracy: 64.0625
# TRAINING - Step: 30, loss: 0.06484510004520416, rolling accuracy: 68.75
# TRAINING - Step: 40, loss: 0.04187338054180145, rolling accuracy: 74.21875
# +++ FEDERATED MODEL 1, EPOCH: 5 +++++++++
# TRAINING - Step: 10, loss: 0.10619989037513733, rolling accuracy: 68.75
# TRAINING - Step: 20, loss: 0.09451019018888474, rolling accuracy: 62.5
# TRAINING - Step: 30, loss: 0.06256423890590668, rolling accuracy: 70.83333587646484
# TRAINING - Step: 40, loss: 0.08360075950622559, rolling accuracy: 70.3125
# +++ FEDERATED MODEL 2, EPOCH: 5 +++++++++
# TRAINING - Step: 10, loss: 0.1653268039226532, rolling accuracy: 71.875
# TRAINING - Step: 20, loss: 0.11843171715736389, rolling accuracy: 60.9375
# TRAINING - Step: 30, loss: 0.13267530500888824, rolling accuracy: 70.83333587646484
# TRAINING - Step: 40, loss: 0.08653954416513443, rolling accuracy: 67.96875
# +++ FEDERATED MODEL 3, EPOCH: 5 +++++++++
# TRAINING - Step: 10, loss: 0.13171541690826416, rolling accuracy: 84.375
# TRAINING - Step: 20, loss: 0.14070634543895721, rolling accuracy: 82.8125
# TRAINING - Step: 30, loss: 0.08975595980882645, rolling accuracy: 82.29167175292969
# TRAINING - Step: 40, loss: 0.1093553826212883, rolling accuracy: 83.59375
# TESTING - Loss: 0.14170049130916595, Accuracy: 90.77743530273438
# +++ FEDERATED MODEL 0, EPOCH: 6 +++++++++
# TRAINING - Step: 10, loss: 0.04035154730081558, rolling accuracy: 96.875
# TRAINING - Step: 20, loss: 0.08157370984554291, rolling accuracy: 93.75
# TRAINING - Step: 30, loss: 0.09792299568653107, rolling accuracy: 85.41667175292969
# TRAINING - Step: 40, loss: 0.08627033233642578, rolling accuracy: 86.71875
# +++ FEDERATED MODEL 1, EPOCH: 6 +++++++++
# TRAINING - Step: 10, loss: 0.053744953125715256, rolling accuracy: 81.25
# TRAINING - Step: 20, loss: 0.08365444839000702, rolling accuracy: 75.0
# TRAINING - Step: 30, loss: 0.1243240088224411, rolling accuracy: 78.12500762939453
# TRAINING - Step: 40, loss: 0.06563214957714081, rolling accuracy: 75.78125
# +++ FEDERATED MODEL 2, EPOCH: 6 +++++++++
# TRAINING - Step: 10, loss: 0.10733035951852798, rolling accuracy: 59.375
# TRAINING - Step: 20, loss: 0.12305552512407303, rolling accuracy: 62.5
# TRAINING - Step: 30, loss: 0.04715654253959656, rolling accuracy: 71.875
# TRAINING - Step: 40, loss: 0.05161518231034279, rolling accuracy: 76.5625
# +++ FEDERATED MODEL 3, EPOCH: 6 +++++++++
# TRAINING - Step: 10, loss: 0.11272535473108292, rolling accuracy: 71.875
# TRAINING - Step: 20, loss: 0.11196562647819519, rolling accuracy: 79.6875
# TRAINING - Step: 30, loss: 0.07710064947605133, rolling accuracy: 80.20833587646484
# TRAINING - Step: 40, loss: 0.11920598149299622, rolling accuracy: 79.6875
# TESTING - Loss: 0.1738169640302658, Accuracy: 92.30182647705078
# +++ FEDERATED MODEL 0, EPOCH: 7 +++++++++
# TRAINING - Step: 10, loss: 0.1313421130180359, rolling accuracy: 87.5
# TRAINING - Step: 20, loss: 0.0959039032459259, rolling accuracy: 68.75
# TRAINING - Step: 30, loss: 0.06914462894201279, rolling accuracy: 76.04167175292969
# TRAINING - Step: 40, loss: 0.03857017308473587, rolling accuracy: 77.34375
# +++ FEDERATED MODEL 1, EPOCH: 7 +++++++++
# TRAINING - Step: 10, loss: 0.06267137825489044, rolling accuracy: 81.25
# TRAINING - Step: 20, loss: 0.10168406367301941, rolling accuracy: 76.5625
# TRAINING - Step: 30, loss: 0.07913432270288467, rolling accuracy: 79.16667175292969
# TRAINING - Step: 40, loss: 0.057920705527067184, rolling accuracy: 80.46875
# +++ FEDERATED MODEL 2, EPOCH: 7 +++++++++
# TRAINING - Step: 10, loss: 0.1649196743965149, rolling accuracy: 78.125
# TRAINING - Step: 20, loss: 0.0722680389881134, rolling accuracy: 67.1875
# TRAINING - Step: 30, loss: 0.09314991533756256, rolling accuracy: 70.83333587646484
# TRAINING - Step: 40, loss: 0.0573771707713604, rolling accuracy: 73.4375
# +++ FEDERATED MODEL 3, EPOCH: 7 +++++++++
# TRAINING - Step: 10, loss: 0.10584898293018341, rolling accuracy: 56.25
# TRAINING - Step: 20, loss: 0.15135186910629272, rolling accuracy: 53.125
# TRAINING - Step: 30, loss: 0.08535490930080414, rolling accuracy: 63.54167175292969
# TRAINING - Step: 40, loss: 0.06187218427658081, rolling accuracy: 67.1875
# TESTING - Loss: 0.1912344992160797, Accuracy: 88.33840942382812
# +++ FEDERATED MODEL 0, EPOCH: 8 +++++++++
# TRAINING - Step: 10, loss: 0.24221202731132507, rolling accuracy: 65.625
# TRAINING - Step: 20, loss: 0.09413004666566849, rolling accuracy: 70.3125
# TRAINING - Step: 30, loss: 0.05714838206768036, rolling accuracy: 69.79167175292969
# TRAINING - Step: 40, loss: 0.09635260701179504, rolling accuracy: 73.4375
# +++ FEDERATED MODEL 1, EPOCH: 8 +++++++++
# TRAINING - Step: 10, loss: 0.12251533567905426, rolling accuracy: 81.25
# TRAINING - Step: 20, loss: 0.2257532924413681, rolling accuracy: 68.75
# TRAINING - Step: 30, loss: 0.13772761821746826, rolling accuracy: 63.54167175292969
# TRAINING - Step: 40, loss: 0.055941060185432434, rolling accuracy: 68.75
# +++ FEDERATED MODEL 2, EPOCH: 8 +++++++++
# TRAINING - Step: 10, loss: 0.07916611433029175, rolling accuracy: 53.125
# TRAINING - Step: 20, loss: 0.07829146832227707, rolling accuracy: 64.0625
# TRAINING - Step: 30, loss: 0.10252082347869873, rolling accuracy: 71.875
# TRAINING - Step: 40, loss: 0.07620604336261749, rolling accuracy: 74.21875
# +++ FEDERATED MODEL 3, EPOCH: 8 +++++++++
# TRAINING - Step: 10, loss: 0.07325427979230881, rolling accuracy: 68.75
# TRAINING - Step: 20, loss: 0.053484007716178894, rolling accuracy: 75.0
# TRAINING - Step: 30, loss: 0.10691426694393158, rolling accuracy: 72.91667175292969
# TRAINING - Step: 40, loss: 0.060472141951322556, rolling accuracy: 75.0
# TESTING - Loss: 0.14719335734844208, Accuracy: 70.3506088256836
# +++ FEDERATED MODEL 0, EPOCH: 9 +++++++++
# TRAINING - Step: 10, loss: 0.08045901358127594, rolling accuracy: 90.625
# TRAINING - Step: 20, loss: 0.07327963411808014, rolling accuracy: 87.5
# TRAINING - Step: 30, loss: 0.059076037257909775, rolling accuracy: 84.37500762939453
# TRAINING - Step: 40, loss: 0.05489463731646538, rolling accuracy: 85.9375
# +++ FEDERATED MODEL 1, EPOCH: 9 +++++++++
# TRAINING - Step: 10, loss: 0.05986796319484711, rolling accuracy: 81.25
# TRAINING - Step: 20, loss: 0.054564185440540314, rolling accuracy: 87.5
# TRAINING - Step: 30, loss: 0.1374664604663849, rolling accuracy: 85.41667175292969
# TRAINING - Step: 40, loss: 0.11330586671829224, rolling accuracy: 81.25
# +++ FEDERATED MODEL 2, EPOCH: 9 +++++++++
# TRAINING - Step: 10, loss: 0.060011692345142365, rolling accuracy: 78.125
# TRAINING - Step: 20, loss: 0.0687875747680664, rolling accuracy: 79.6875
# TRAINING - Step: 30, loss: 0.05731938034296036, rolling accuracy: 76.04167175292969
# TRAINING - Step: 40, loss: 0.10466042160987854, rolling accuracy: 80.46875
# +++ FEDERATED MODEL 3, EPOCH: 9 +++++++++
# TRAINING - Step: 10, loss: 0.05797846242785454, rolling accuracy: 90.625
# TRAINING - Step: 20, loss: 0.1445583701133728, rolling accuracy: 70.3125
# TRAINING - Step: 30, loss: 0.08580175042152405, rolling accuracy: 70.83333587646484
# TRAINING - Step: 40, loss: 0.11762700974941254, rolling accuracy: 74.21875
# TESTING - Loss: 0.0981147438287735, Accuracy: 63.8719482421875
# +++ FEDERATED MODEL 0, EPOCH: 10 +++++++++
# TRAINING - Step: 10, loss: 0.027970563620328903, rolling accuracy: 96.875
# TRAINING - Step: 20, loss: 0.04990964010357857, rolling accuracy: 87.5
# TRAINING - Step: 30, loss: 0.08117100596427917, rolling accuracy: 84.37500762939453
# TRAINING - Step: 40, loss: 0.05779610574245453, rolling accuracy: 82.8125
# +++ FEDERATED MODEL 1, EPOCH: 10 +++++++++
# TRAINING - Step: 10, loss: 0.2263546884059906, rolling accuracy: 75.0
# TRAINING - Step: 20, loss: 0.0832308828830719, rolling accuracy: 71.875
# TRAINING - Step: 30, loss: 0.09847144782543182, rolling accuracy: 76.04167175292969
# TRAINING - Step: 40, loss: 0.38980624079704285, rolling accuracy: 78.125
# +++ FEDERATED MODEL 2, EPOCH: 10 +++++++++
# TRAINING - Step: 10, loss: 0.06577998399734497, rolling accuracy: 81.25
# TRAINING - Step: 20, loss: 0.16582021117210388, rolling accuracy: 71.875
# TRAINING - Step: 30, loss: 0.060185518115758896, rolling accuracy: 75.00000762939453
# TRAINING - Step: 40, loss: 0.10969212651252747, rolling accuracy: 78.125
# +++ FEDERATED MODEL 3, EPOCH: 10 +++++++++
# TRAINING - Step: 10, loss: 0.05099298432469368, rolling accuracy: 75.0
# TRAINING - Step: 20, loss: 0.056626297533512115, rolling accuracy: 81.25
# TRAINING - Step: 30, loss: 0.03250191733241081, rolling accuracy: 84.37500762939453
# TRAINING - Step: 40, loss: 0.0819806158542633, rolling accuracy: 84.375
# TESTING - Loss: 0.16555054485797882, Accuracy: 84.2225570678711
